# %% [markdown]
# Emisiones de Gases de Efecto Invernadero
#
# Luis Enrique Vallarta Robledo
#
# Descripción de los Datos
# El documento fuente viene de la ONU (FAO) y contiene información de las emisiones de Gases de Efecto Invernadero (GEI).
# El objetivo de éste análisis es es entender cuales son los GEIs que más se generan y en que región o país se generan.

# %% [markdown]
# Contenido
#
# 1. Fuentes de datos
#
# 2. Descripción de los datos
#
# 3. Valores faltantes y limpieza de datos
#
# 4. Visualización de datos
#
# 5. Comentarios adicionales
#
# 6. Referencias

# %% [markdown]
# 1. Fuentes de datos
#
# Los datos fueron obtenidos de la página de la ONU enfocada a los alimentos y la agricultura, la FAO: https://www.fao.org/faostat/en/#data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Subir dataset
file = "Emissions_Totals_E_All_Data_NOFLAG.csv"
archivo = pd.read_csv(file)

# %% [markdown]
# 2. Descripción de los datos

# %%
# SGuardar descripción de variables
descripcion = archivo.iloc[0].to_dict()
descripcion
# Out:
# {'Area Code': 2,
#  'Area Code (M49)': "'004",
#  'Area': 'Afghanistan',
#  'Item Code': 5064,
#  'Item': 'Crop Residues',
#  'Element Code': 7234,
#  'Element': 'Direct emissions (N2O)',
#  'Source Code': 3050,
#  'Source': 'FAO TIER 1',
#  'Unit': 'kilotonnes',
#  'Y1961': 0.8762,
#  'Y1962': 0.8829,
#  'Y1963': 0.8236,
#  'Y1964': 0.8882,
#  'Y1965': 0.8978,
#  'Y1966': 0.8466,
#  'Y1967': 0.8783,
#  'Y1968': 0.8886,
#  'Y1969': 0.9123,
#  'Y1970': 0.8304,
#  'Y1971': 0.8093,
#  'Y1972': 0.9531,
#  'Y1973': 0.9725,
#  'Y1974': 0.988,
#  'Y1975': 1.0138,
#  'Y1976': 1.0401,
#  'Y1977': 0.9566,
#  'Y1978': 0.9972,
#  'Y1979': 0.9533,
#  'Y1980': 0.9156,
#  'Y1981': 0.8766,
#  'Y1982': 0.8407,
#  'Y1983': 0.8065,
#  'Y1984': 0.7713,
#  'Y1985': 0.7319,
#  'Y1986': 0.6981,
#  'Y1987': 0.7706,
#  'Y1988': 0.6917,
#  'Y1989': 0.6601,
#  'Y1990': 0.6334,
#  'Y1991': 0.6454,
#  'Y1992': 0.6054,
#  'Y1993': 0.711,
#  'Y1994': 0.7456,
#  'Y1995': 0.7511,
#  'Y1996': 0.7672,
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58764 entries, 0 to 58763
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Source  58764 non-null  object
#  1   Y1961   9646 non-null   float64
#  2   Y1965   9656 non-null   float64
#  3   Y1966   9671 non-null   float64
#  4   Y1967   9679 non-null   float64
#  5   Y1968   9705 non-null   float64
#  6   Y1969   9715 non-null   float64
#  7   Y1970   9723 non-null   float64
#  8   Y1971   9733 non-null   float64
#  9   Y1972   9753 non-null   float64
#  10  Y1973   9758 non-null   float64
#  11  Y1974   9773 non-null   float64
#  12  Y1975   9793 non-null   float64
#  13  Y1976   9798 non-null   float64
#  14  Y1977   9798 non-null   float64
#  15  Y1978   9793 non-null   float64
#  16  Y1979   9798 non-null   float64
#  17  Y1980   9803 non-null   float64
#  18  Y1981   9810 non-null   float64
#  19  Y1982   9810 non-null   float64
# ...

# %%
# Columnas del dataset
print("Este dataset contiene información de los principales gases de efecto invernadero generados por el ser humano por país en un tiempo determinado y divididos por el medio por el que se genera.")
df = archivo.drop([0])
df.head()
# Out:
# Este dataset contiene información de los principales gases de efecto invernadero generados por el ser humano por país en un tiempo determinado y divididos por el medio por el que se genera.
#    Area Code Area Code (M49)         Area  Item Code              Item  \
# 1          2            '004  Afghanistan       5064     Crop Residues
# 2          2            '004  Afghanistan       5064     Crop Residues
# 3          2            '004  Afghanistan       5064     Crop Residues
# 4          2            '004  Afghanistan       5064     Crop Residues
# 5          2            '004  Afghanistan       5060  Rice Cultivation
#
#    Element Code                           Element  Source Code      Source  \
# 1          7236          Indirect emissions (N2O)         3050  FAO TIER 1
# 2          7230                   Emissions (N2O)         3050  FAO TIER 1
# 3        724313  Emissions (CO2eq) from N2O (AR5)         3050  FAO TIER 1
# ...

# %%
# Variables
df.columns
# Out:
# Index(['Area Code', 'Area Code (M49)', 'Area', 'Item Code', 'Item',
#        'Element Code', 'Element', 'Source Code', 'Source', 'Unit', 'Y1961',
#        'Y1962', 'Y1963', 'Y1964', 'Y1965', 'Y1966', 'Y1967', 'Y1968', 'Y1969',
#        'Y1970', 'Y1971', 'Y1972', 'Y1973', 'Y1974', 'Y1975', 'Y1976', 'Y1977',
#        'Y1978', 'Y1979', 'Y1980', 'Y1981', 'Y1982', 'Y1983', 'Y1984', 'Y1985',
#        'Y1986', 'Y1987', 'Y1988', 'Y1989', 'Y1990', 'Y1991', 'Y1992', 'Y1993',
#        'Y1994', 'Y1995', 'Y1996', 'Y1997', 'Y1998', 'Y1999', 'Y2000', 'Y2001',
#        'Y2002', 'Y2003', 'Y2004', 'Y2005', 'Y2006', 'Y2007', 'Y2008', 'Y2009',
#        'Y2010', 'Y2011', 'Y2012', 'Y2013', 'Y2014', 'Y2015', 'Y2016', 'Y2017',
#        'Y2018', 'Y2019', 'Y2020', 'Y2021', 'Y2030', 'Y2050'],
#       dtype='object')

# %%
# Número de términos únicos por variable
df.nunique()
# Out:
# Area Code            280
# Area Code (M49)      280
# Area                 280
# Item Code             42
# Item                  42
#                    ...
# Y2019              32252
# Y2020              32310
# Y2021                  1
# Y2030               7342
# Y2050               7424
# Length: 73, dtype: int64

# %% [markdown]
# 3. Valores faltantes y limpieza de datos

# %%
# Revisar los valores nulos
df.isnull().sum()
# Out:
# Area Code              0
# Area Code (M49)        0
# Area                   0
# Item Code              0
# Item                   0
#                    ...
# Y2019               4777
# Y2020               5094
# Y2021              58694
# Y2030              40769
# Y2050              40764
# Length: 73, dtype: int64

# %%
print("Quitamos valores nulos")
df_limpiar = df[df != -999999].dropna(axis=1)
print(df_limpiar)
# Out:
# Quitamos valores nulos
#        Area Code Area Code (M49)         Area  Item Code  \
# 1              2            '004  Afghanistan       5064
# 2              2            '004  Afghanistan       5064
# 3              2            '004  Afghanistan       5064
# 4              2            '004  Afghanistan       5064
# 5              2            '004  Afghanistan       5060
# ...          ...             ...          ...        ...
# 58760       5873            '198         OECD       6829
# 58761       5873            '198         OECD       6829
# 58762       5873            '198         OECD       6829
# 58763       5873            '198         OECD       6829
# 58764       5873            '198         OECD       6829
#
#                              Item  Element Code  \
# 1                   Crop Residues          7236
# 2                   Crop Residues          7230
# 3                   Crop Residues        724313
# 4                   Crop Residues        723113
# ...

# %%
print("Los valores tienen el tipo de dato adecuado")
df.dtypes
# Out:
# Los valores tienen el tipo de dato adecuado
# Area Code            int64
# Area Code (M49)     object
# Area                object
# Item Code            int64
# Item                object
#                     ...
# Y2019              float64
# Y2020              float64
# Y2021              float64
# Y2030              float64
# Y2050              float64
# Length: 73, dtype: object

# %%
print("Se eliminan las columnas con información irrelevente")
df = df.drop(df.columns[[0, 1,3,5,6,7]], axis='columns')
# Out:
# Se eliminan las columnas con información irrelevente

# %% [markdown]
# 4. Visualización de datos

# %%
# Actualizar index de base de datos
df.reset_index(drop=True, inplace=True)

# %%
print("Emisiones de gases de efecto invernadero por fuente de generación")
x = archivo['Y2020'].values.tolist() 
y = archivo['Item'].values.tolist() 
plt.figure(figsize=(12,8))
plt.plot(x,y,'.')
# Out:
# Emisiones de gases de efecto invernadero por fuente de generación

# %%
print("Emisiones de gases de efecto por tipo de gas")
x = archivo['Y2020'].values.tolist() 
y = archivo['Element'].values.tolist() 
plt.figure(figsize=(12,8))
plt.plot(x,y,'.')
# Out:
# Emisiones de gases de efecto por tipo de gas

# %%
print("Emisiones de GEIs de 1961 al 2020, Nota: incluye proyecciones hacia 2050")
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc = {'figure.figsize':(15,8)})
sns.lineplot(data=df)
# Out:
# Emisiones de GEIs de 1961 al 2020, Nota: incluye proyecciones hacia 2050
# <AxesSubplot:>

# %% [markdown]
# 5- Comentarios adicionales

# %% [markdown]
# Para poder tener conclusiones más especificas es necesario un análisis más detallado, sin embargo podemos observar un incremento en la generación de los gases de efecto invernadero de 1961 a la fecha actual, de igual manera podemos observar una tendencia creciente hacia 2030 y 2050 por lo que incluir estrategias para disminuir la generación de GEIs a nivel mundial sería necesario para evitar catastrofes medioambientales y migración de poblaciones. Llaman la atención 2 gases en particular cuando hablamos del total de las emisiones, el C02 y el Metano, por lo que sería importante hacer un análisis más detallado para entender como se generan y evaluar si es posible disminuir su generación.

# %% [markdown]
# 6. Referencias

# %%
#FAOSTAR (2023). https://www.fao.org/faostat/en/#data
